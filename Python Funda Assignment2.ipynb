# %% [markdown]
# LIST

# %% [markdown]
# Create a list named age_list with five integer elements

# %%
age_list = [15,34,51,7,29]

# %% [markdown]
# Create a list named name_list with five string elements

# %%
name_list = ["Raju", "Radha", "Bhim", "Nobita", "Jackie"]

# %%
print(name_list)
print(age_list)
# Out:
# ['Raju', 'Radha', 'Bhim', 'Nobita', 'Jackie']
# [15, 34, 51, 7, 29]

# %% [markdown]
# Append "Yazhini" to name_list

# %%
name_list.append("Yazhini")

# %%
print(name_list)
# Out:
# ['Raju', 'Radha', 'Bhim', 'Nobita', 'Jackie', 'Yazhini']

# %% [markdown]
# Insert 30 at index 2 in age_list

# %%
age_list.insert(2, 30)

# %%
print(age_list)
# Out:
# [15, 34, 30, 51, 7, 29]

# %% [markdown]
# Remove "Yazhini" from name_list

# %%
name_list.remove("Yazhini")

# %%
print(name_list)
# Out:
# ['Raju', 'Radha', 'Bhim', 'Nobita', 'Jackie']

# %% [markdown]
# Pop the last element from age_list

# %%
age_list.pop()
# Out:
# 29

# %%
print(age_list)
# Out:
# [15, 34, 30, 51, 7]

# %% [markdown]
# Extend age_list with additional ages

# %%
age_list.extend([1,43,19,70])

# %%
print(age_list)
# Out:
# [15, 34, 30, 51, 7, 1, 43, 19, 70]

# %% [markdown]
# Sort age_list in descending order

# %%
age_list.sort(reverse=True)

# %% [raw]
# print(age_list)

# %% [markdown]
# Find maximum age, minimum age, and sum of all age

# %%
max_age = max(age_list)
min_age = min(age_list)
total_age = sum(age_list)

# %%
print( max_age)
print( min_age)
print(total_age)
# Out:
# 70
# 1
# 270

# %% [markdown]
# Print the first element of name_list

# %%
print("First element:", name_list[0])
# Out:
# First element: Raju

# %% [markdown]
# Print the last element of name_list

# %%
print("Last element:", name_list[-1])
# Out:
# Last element: Jackie

# %% [markdown]
# Print elements from index 2 to index 4

# %%
print("Elements from index 2 to 4:", name_list[2:5])
# Out:
# Elements from index 2 to 4: ['Bhim', 'Nobita', 'Jackie']

# %% [markdown]
#  Print the elements of name_list in reverse order

# %%
print("Reverse order:", name_list[::-1])
# Out:
# Reverse order: ['Jackie', 'Nobita', 'Bhim', 'Radha', 'Raju']

# %% [markdown]
# DICTIONARY

# %% [markdown]
# Create a dictionary named student_marks that maps the names of five
# students to their marks (use scale of from 0 to 100).

# %%
student_marks = {
    "Raju": 25,
    "Radha": 17,
    "Bhim": 23,
    "Nobita": 9,
    "Jackie": 21
}

# %%
print(student_marks)
# Out:
# {'Raju': 25, 'Radha': 17, 'Bhim': 23, 'Nobita': 9, 'Jackie': 21}

# %% [markdown]
# Access and print the mark of a specific student, of your choice.

# %%
print(student_marks["Nobita"])
# Out:
# 9

# %% [markdown]
# Add a new student "Janani" with a mark of 80 to the student_marks dictionary

# %%
student_marks["Janani"] = 80

# %%
print(student_marks)
# Out:
# {'Raju': 25, 'Radha': 17, 'Bhim': 23, 'Nobita': 9, 'Jackie': 21, 'Janani': 80}

# %% [markdown]
# Update the mark of an older student to 82

# %%
student_marks["Bhim"] = 82

# %%
print(student_marks)
# Out:
# {'Raju': 25, 'Radha': 17, 'Bhim': 82, 'Nobita': 9, 'Jackie': 21, 'Janani': 80}

# %% [markdown]
# Use the keys(), values(), and items() methods to print all keys, values, and
# key-value pairs in the student_marks dictionary.

# %%
print("Keys:", student_marks.keys())
print("Values:", student_marks.values())
print("Key-Value Pairs:", student_marks.items())
# Out:
# Keys: dict_keys(['Raju', 'Radha', 'Bhim', 'Nobita', 'Jackie', 'Janani'])
# Values: dict_values([25, 17, 82, 9, 21, 80])
# Key-Value Pairs: dict_items([('Raju', 25), ('Radha', 17), ('Bhim', 82), ('Nobita', 9), ('Jackie', 21), ('Janani', 80)])

# %% [markdown]
# Sets (Operations):

# %% [markdown]
# Create a set called my_set with following values:
# ['a','e','i','o','u','a','a','i']

# %%
my_set = {'a', 'e', 'i', 'o', 'u', 'a', 'a', 'i'}

# %%
print(my_set)
# Out:
# {'u', 'i', 'e', 'a', 'o'}

# %%
print(len(my_set))
# Out:
# 5

# %% [markdown]
# Attempt to change the value of my_set[4] = 's'. If code throws an error, provide
# an explanation.

# %%
my_set[4] = 's'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 my_set[4] = 's'
#
# TypeError: 'set' object does not support item assignment

# %% [markdown]
# Explanation:
# Sets are also mutable, meaning we can add or remove elements, but individual elements cannot be changed using an index.

# %% [markdown]
# Create two sets:
# set1 with values: {1, 3, 5, 7, 9}
# set2 with values: {2, 3, 5, 8, 10}

# %%
set1 = {1, 3, 5, 7, 9}
set2 = {2, 3, 5, 8, 10}

# %%
print(set1)
print(set2)
# Out:
# {1, 3, 5, 7, 9}
# {2, 3, 5, 8, 10}

# %% [markdown]
# Compute and print the union and intersection of set1 and set2

# %%
union_set = set1.union(set2)
intersection_set = set1.intersection(set2)

# %%
print(union_set)
print(intersection_set)
# Out:
# {1, 2, 3, 5, 7, 8, 9, 10}
# {3, 5}

# %% [markdown]
# Operators & Conditional Statements :
# (IF, ELIF, ELSE)

# %% [markdown]
# 1. Prompt user for Input. Score range should be from 0 to 10 (both inclusive)

# %%
score = float(input("Enter your score (0 to 10): "))
# Out:
# Enter your score (0 to 10):  5

# %%
if score < 0 or score > 10:
    print("Invalid score! Please enter a score between 0 and 10.")

# %%
score = float(input("Enter your score (0 to 10): "))

if score < 0 or score > 10:
    print("Invalid score! Please enter a score between 0 and 10.")

elif score > 7:
    print("Above Average: Excellent performance! Keep up the great work!")

elif score >= 4:
    print("Average: Good effort! Keep practicing, there's room for improvement.")

else:
    print("Below Average: Need to improve your performance. Consistent practice will lead to better results.")
# Out:
# Enter your score (0 to 10):  7
# Average: Good effort! Keep practicing, there's room for improvement.
